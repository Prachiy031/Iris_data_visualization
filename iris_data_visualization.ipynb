# %% [markdown]
# Using all libraries for iris dataset

# %%
#import all libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = sns.load_dataset('iris')          #load inbuilt dataset

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.columns             #find out columns in ds
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.values          #find out values in ds
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
df.isnull().sum()  #find out total null values
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].value_counts()        #species is target feature
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df['species'].count()      #find out count of each category in species
# Out:
# 150

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.iloc[:,-1]          #indexing
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df.iloc[2:3]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df['species'].unique()          #finding out unique species
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df['sepal_width'].mean()
# Out:
# 3.0573333333333337

# %%
df['sepal_length'].mode()
# Out:
# 0    5.0
# Name: sepal_length, dtype: float64

# %%
df['sepal_length'].median()
# Out:
# 5.8

# %%
s_width = df['sepal_width']
s_length = df['sepal_length']
p_width = df['petal_width']
p_length = df['petal_length']
species = df['species']

# %%
plt.scatter(s_length,p_length)    #scatter plot

# %%
plt.scatter(s_width,p_width)

# %%
plt.plot(s_width,species,'r--')            #plot graph
plt.xlabel('s_width')
plt.ylabel('species')
plt.title('relation between s_width and species')
# Out:
# Text(0.5, 1.0, 'relation between s_width and species')

# %%
plt.hist(s_length,bins=10)  #histogram
plt.xlabel('s_length')
plt.ylabel('count')
plt.title('relation between s_length and count')
# Out:
# Text(0.5, 1.0, 'relation between s_length and count')

# %%
values = df.select_dtypes(include='number')           #selecting only numerical data 
plt.boxplot(values,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x263d3e0f390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x263d3f33290>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x263d3ef8cd0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x263d3f40850>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x263d3f045d0>,
# ...
#  'means': []}

# %%
# The diagonal elements in a pairplot show the histogram by default
# We can update these elements to show other things, such as a kde
sns.pairplot(df, hue="species", size=3, diag_kind="kde")
# Out:
# C:\Users\Prachi Yadav\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Prachi Yadav\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=df,size=4)

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
labels = df['species'].unique()

# %%
labels
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
count = df['species'].value_counts()

# %%
count
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
explode = [0.3,0,0.3]
colors = ['red','green','yellow']

# %%
plt.pie(count,labels = labels,explode = explode,colors = colors,autopct = "%1.1f%%",shadow = True)  #pie chart
plt.axis('equal')
plt.show()

# %%
corr_matrix = values.corr()     #correlation matrix

# %%
corr_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
plt.figure(1,figsize=(12,5))
sns.heatmap(corr_matrix,center=0,cbar=False,cmap='BrBG',annot=True,linewidth=0.3,linecolor = 'white')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'species',data=df)    #count plot for only categorical data
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.barplot(x = 'species',y='sepal_length',data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
#box plot
sns.boxplot(x='species',y='sepal_length', data=df)        #boxplot
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(x='sepal_width',y='species',data=df,palette='rainbow')  #violin plot
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>
